# %%
# example_sparql_wrapper
# Send SPARQL query to SPARQL endpoint, store and output result
# using SPARQLWrapper
#
# modified from ORA "Learning SPARQL" by Bob DuCharme -- ex361.py
#

from SPARQLWrapper import SPARQLWrapper, JSON

# %%
## This was not the correct endpoint 
# endpointURL = "http://mmisw.org/ont/?sparql"

sparql = SPARQLWrapper("http://mmisw.org/sparql")
queryString = """
PREFIX ioos: <http://mmisw.org/ont/ioos/parameter/>
SELECT DISTINCT ?parameter ?definition ?unit ?property ?value 
WHERE {?parameter a ioos:Parameter .
       # ?parameter ?property ?value .
       # ?parameter ioos:Term ?term . 
       # ?parameter ioos:Definition ?definition . 
       # ?parameter ioos:Units ?unit .
       FILTER (regex(str(?property), "(exactMatch|closeMatch)", "i") && regex(str(?value), "cf", "i") )
      } 
ORDER BY ?parameter
"""

# %%
sparql.setQuery(queryString)
sparql.setReturnFormat(JSON)
j = sparql.query().convert()

# %%
j.keys()
# Out:
# [u'head', u'results']

# %%
j["head"]["vars"]
# Out:
# [u'parameter', u'definition', u'unit', u'property', u'value']

# %%
j
# Out:
# {u'names': [u'parameter', u'definition', u'unit', u'property', u'value'],
#  u'values': [[u'<http://mmisw.org/ont/ioos/parameter/air_pressure>',
#    u'"Pressure exerted by overlying air"',
#    u'"hPa"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/air_pressure>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/air_temperature>',
#    u'"Temperature of air in situ."',
#    u'"celcius"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/air_temperature>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/altitude>',
#    u'"Z-coordinate of observation in vertical distance above reference. Up is positive.  (sea surface | geiod | ellipsoid | MSL | MLLW | AGL)"',
#    u'"meter"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/altitude>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/bottom_tracking_velocity>',
#    u'"In vessel-mounted ADCP applications, bottom tracking can be used to accurately remove platform velocity from profile velocities. When the sea-floor bottom is within range of the ADCP, a special ping can be transmitted to measure the Doppler shift of the signal return from the bottom, providing a very accurate measurement of ship velocity.  When bottom-tracking is unavailable (too deep for ADCP to sense sea-floor), ship navigation data is used to estimate ship velocity."',
#    u'"degrees"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/platform_speed_wrt_ground>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/conductivity>',
#    u'"Ability of a material to pass an electrical current.  Inverse of resistance. In water, it is a proxy from which salinity is derived for water quality or to further derive water density."',
#    u'"siemens | uS"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_electrical_conductivity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/current_to_direction>',
#    u'"Direction towards which ocean current is going. Oceanographic convention. Current is the steady flow of water along a cyclic or directional path relative to location and time."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/direction_of_sea_water_velocity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/current_velocity>',
#    u'"The vector quantity of speed and direction or geographic components of speed of current flow. Current is the steady flow of water along a cyclic or directional path relative to location and time."',
#    u'"cm s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_speed>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/depth>',
#    u'"Z-coordinate of observation in vertical distance below reference. Down is positive. (sea surface | geiod | ellipsoid | MSL | MLLW | AGL )"',
#    u'"meter"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/depth>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/dissolved_inorganic_carbon>',
#    u'"Total dissolved inorganic carbon (DIC) is the sum of gaseous CO2, bicarbonate and carbonate is the major carbon reservoir in the ocean.  DIC content is expressed as mole of Carbon to mass of seawater."',
#    u'"umol kg-1"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_inorganic_carbon_in_sea_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/dissolved_organic_carbon>',
#    u'"Dissolved Organic Carbon (DOC) is used to describe the thousands of dissolved compounds found in water that derive from organic materials. DOC mostly consists of long-chain organic molecules, but smaller species, such as methane, are also considered organic."',
#    u'"umol l-1"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/mole_concentration_of_dissolved_organic_carbon_in_sea_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/dissolved_oxygen>',
#    u'"Concentration of dissolved oxygen (DO) in water and can be measured by laboratory chemical analysis,  electrochemical or optical probes.   DO concentration is highly dependent on temperature and salinity."',
#    u'"mg L-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/mass_concentration_of_oxygen_in_sea_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/dissolved_oxygen_saturation>',
#    u'"Dissolved Oxygen Saturation (DO%) is DO concentraion relative to DO saturation levels at the same temperature and salinity in a water sample."',
#    u'"%"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/fractional_saturation_of_oxygen_in_sea_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/eastward_current>',
#    u'"East/West component of ocean current. Eastward is positive. Current is the steady flow of water along a cyclic or directional path relative to location and time."',
#    u'"cm s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/eastward_sea_water_velocity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/eastward_wind>',
#    u'"East/West component of wind vector. Eastward wind is positive.  Wind is motion of air relative to the surface of the earth."',
#    u'"m s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/eastward_wind>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/eastward_wind_stress>',
#    u'"East/West component of wind stress. Eastward is positive."',
#    u'"N m-2"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/surface_downward_eastward_stress>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/electromagnetic_wavelength>',
#    u'"Specific frequency of energy within the electromagnetic spectrum."',
#    u'"m"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/radiation_wavelength>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/heading>',
#    u'"The direction towards an object relative to a fixed reference, usually a geographic frame of reference, such as True North."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/platform_course>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/latitude>',
#    u'"Y-coordinate of dependent observation in geographic coordinate. North is positive."',
#    u'"degrees_north"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/latitude>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/longitude>',
#    u'"X-coordinate of dependent observation in geographic coordinate. East is positive."',
#    u'"degrees_east"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/longitude>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/northward_current>',
#    u'"North/South component of ocean current. Northward is positive. Current is the steady flow of water along a cyclic or directional path relative to location and time."',
#    u'"cm s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/northward_sea_water_velocity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/northward_wind>',
#    u'"North/South component of wind vector. Northward wind is positive. Wind is motion of air relative to the surface of the earth."',
#    u'"m s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/northward_wind>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/northward_wind_stress>',
#    u'"North/South component of wind stress. Northward is positive. Wind is motion of air relative to the surface of the earth.  Wind stress is the force of wind imposed on a unit area."',
#    u'"N m-2"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/surface_downward_northward_stress>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/peak_wave_period>',
#    u'"The wave period as inverse of wave frequency at which the wave spectrum reaches its maximum.  Sometimes referred to as the dominant wave period."',
#    u'"s"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_surface_wave_period_at_variance_spectral_density_maximum>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/pitch>',
#    u'"Rotation about the lateral axis of a sensor platform like a ship or buoy or bottom frame."',
#    u'"degree"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/platform_pitch_angle>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/radial_direction>',
#    u'"Bearing from an HF Radar site that defines the directional component of the radial velocity vector observed.  The final and third step in processng HF Radar returned signal is to determine the bearing angle or direction of the patch of scatterers based on each speed and each range found in the first two steps."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/direction_of_radial_vector_away_from_instrument>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/radial_velocity>',
#    u'"For HF Radar surface current applications, it is the velocity of the scattering medium of a specific area defined by the bearing and distance from the sensing antenna.  Radial velocity is a vector quantity of range bin, radial speed, and radial direction."',
#    u'"cm s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/radial_sea_water_velocity_away_from_instrument>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/roll>',
#    u'"Rotation about the longitudinal axis of a sensor platform like a ship or buoy or bottom frame."',
#    u'"degree"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/platform_roll_angle>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/secchi_disk_depth>',
#    u'"A measure of visibility or transparency in water. A Secchi Disk is a patterned disk that is lowered into the water and the depth at which the pattern is no longer visible is the called the Secchi Disk depth (SDD)."',
#    u'"m"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/secchi_depth_of_sea_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/signal_strength>',
#    u'"In radar, the power of the signal transmitted or received.   Signal strength is generally expressed in decibels relative to some standard value,  commonly 1 milliwatt or relative to power received at same distance of a signal transmitted in a vacuum."',
#    u'"dBm | mW"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sound_intensity_level_in_water>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/signal_strength>',
#    u'"In radar, the power of the signal transmitted or received.   Signal strength is generally expressed in decibels relative to some standard value,  commonly 1 milliwatt or relative to power received at same distance of a signal transmitted in a vacuum."',
#    u'"dBm | mW"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sound_intensity_level_in_air>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/significant_wave_height>',
#    u'"The mean height of highest third of the waves recorded during a sampling period.  It is also estimated from measured wave energy, as four times the square-root of the first moment of the wave spectrum."',
#    u'"meter"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_surface_wave_significant_height>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/surface_elevation>',
#    u'"Height or altitude of the sea surface above specified reference."',
#    u'"meter"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/water_surface_height_above_reference_datum>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/surface_elevation>',
#    u'"Height or altitude of the sea surface above specified reference."',
#    u'"meter"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/surface_altitude>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/total_alkalinity>',
#    u'"A measure of the buffering capacity of water or the ability of a solution to neutralize acid. Total alkalinity is a measure of the amount of negatively charged ions in a given amount of water. In the oceans, most of the negatively charged ions present are bicarbonate (HCO3-) and carbonate (CO3--).  Combined with DIC measurments, total alkalinity is used to calculate the pCO2 for a volume of water."',
#    u'"mEq l-1"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_alkalinity_expressed_as_mole_equivalent>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/upward_wind>',
#    u'"Vertical wind velocity. Up/Down component of wind vector. Up is positive. Wind is motion of air relative to the surface of the earth."',
#    u'"m s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/upward_air_velocity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/vertical_current>',
#    u'"Upward/Downward component of ocean current. Upward is positive. Current is the steady flow of water along a cyclic or directional path relative to location and time."',
#    u'"cm s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/upward_sea_water_velocity>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/water_density>',
#    u'"Mass of water per unit volume."',
#    u'"kg m-3"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_density>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/water_pressure>',
#    u'"Pressure exerted by overlying air and water."',
#    u'"Pa"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_pressure>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/water_temperature>',
#    u'"In situ temperature of the ocean."',
#    u'"celcius"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_water_temperature>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wave_frequency>',
#    u'"Frequency is the number of oscillations of a wave per unit time.  The inverse of wave_period."',
#    u'"s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/wave_frequency>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wave_from_direction>',
#    u'"The direction from which a wave approaches."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_surface_wave_from_direction>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wave_to_direction>',
#    u'"The direction toward which a wave propagates."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/sea_surface_wave_to_direction>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wind_from_direction>',
#    u'"Direction from which wind is blowing.  Meteorological Convention. Wind is motion of air relative to the surface of the earth."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/wind_from_direction>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wind_gust>',
#    u'"Maximum instantaneous wind speed (usually no more than but not limited to 10 seconds) within a sample averaging interval. Wind is motion of air relative to the surface of the earth."',
#    u'"m s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/wind_speed_of_gust>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wind_speed>',
#    u'"Magnitude of wind velocity. Wind is motion of air relative to the surface of the earth."',
#    u'"m s-1"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/wind_speed>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wind_stress>',
#    u'"Magnitude of wind stress. Wind is motion of air relative to the surface of the earth.  Wind stress is the force of wind imposed on a unit area."',
#    u'"N m-2"',
#    u'<http://www.w3.org/2004/02/skos/core#closeMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/magnitude_of_surface_downward_stress>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/wind_to_direction>',
#    u'"Direction toward which wind is blowing.  Oceanographic convention. Wind is motion of air relative to the surface of the earth."',
#    u'"degrees_true"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/wind_to_direction>'],
#   [u'<http://mmisw.org/ont/ioos/parameter/yaw>',
#    u'"Rotation about the vertical axis of a sensor platform like a ship or buoy or bottom frame."',
#    u'"degree"',
#    u'<http://www.w3.org/2004/02/skos/core#exactMatch>',
#    u'<http://mmisw.org/ont/cf/parameter/platform_yaw_angle>']]}
